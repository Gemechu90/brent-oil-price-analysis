# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import wbdata
import datetime
import logging
from typing import Dict, Optional

import warnings
warnings.filterwarnings('ignore')

# %%
# Add the parent directory to the system path 
import os
import sys
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
from scripts.economic_analysis import *

# %%
oil_prices_df=pd.read_csv('../Data/BrentOilPrices.csv')

# %% [markdown]
# ## Economic Indicators
#  fetche and processes various economic indicators to analyze their influence on oil prices.
#
# - GDP growth
# - Inflation rates
# - Unemployment rates
# - Renewable energy consumption
# - Environmental tax revenue
# - Trade balance
# - Natural gas usage
# - Exchange rates for major currencies

# %%
logger.info("Starting data collection...")
indicator_data = fetch_all_indicators()
    
# Merge all indicators
merged_data = merge_indicators(indicator_data)
# Out:
# 2025-02-25 10:38:04,332 - INFO - Starting data collection...
# 2025-02-25 10:38:06,162 - INFO - Successfully fetched GDP Growth (%) data
# 2025-02-25 10:38:07,068 - INFO - Successfully fetched Inflation Rate (%) data
# 2025-02-25 10:38:07,918 - INFO - Successfully fetched Unemployment Rate (%) data
# 2025-02-25 10:38:08,820 - INFO - Successfully fetched Exchange Rate (Local Currency per USD) data
# 2025-02-25 10:38:09,361 - INFO - Successfully fetched Renewable Energy Consumption (%) data
# 2025-02-25 10:38:10,255 - INFO - Successfully fetched Environmental Tax Revenue (% of GDP) data
# 2025-02-25 10:38:10,812 - INFO - Successfully fetched Net Trade (BoP, current US$) data
# 2025-02-25 10:38:11,355 - INFO - Successfully fetched Natural Gas Electricity Production (%) data
# 2025-02-25 10:38:11,535 - INFO - Successfully merged all indicators

# %%
# Display summary of collected data
for name, df in indicator_data.items():
    print(df.head())
        
print("\nMerged Data Summary:")
merged_data.head()
print(f"Final Shape: {merged_data.shape}")
# Out:
#                 country       date  GDP Growth (%)
# 1  United Arab Emirates 2022-01-01    5.027319e+11
# 2  United Arab Emirates 2021-01-01    4.151788e+11
# 3  United Arab Emirates 2020-01-01    3.494730e+11
# 4  United Arab Emirates 2019-01-01    4.179897e+11
# 5  United Arab Emirates 2018-01-01    4.270494e+11
#                 country       date  Inflation Rate (%)
# 1  United Arab Emirates 2022-01-01          118.289445
# 2  United Arab Emirates 2021-01-01          112.345016
# 3  United Arab Emirates 2020-01-01          112.143231
# 4  United Arab Emirates 2019-01-01          114.524661
# 5  United Arab Emirates 2018-01-01          116.779773
#                 country       date  Unemployment Rate (%)
# 1  United Arab Emirates 2022-01-01                  2.872
# 2  United Arab Emirates 2021-01-01                  3.105
# 3  United Arab Emirates 2020-01-01                  4.294
# 4  United Arab Emirates 2019-01-01                  2.331
# 5  United Arab Emirates 2018-01-01                  2.236
#                 country       date  Exchange Rate (Local Currency per USD)
# 1  United Arab Emirates 2022-01-01                                  3.6725
# 2  United Arab Emirates 2021-01-01                                  3.6725
# 3  United Arab Emirates 2020-01-01                                  3.6725
# 4  United Arab Emirates 2019-01-01                                  3.6725
# 5  United Arab Emirates 2018-01-01                                  3.6725
#                 country       date  Renewable Energy Consumption (%)
# 1  United Arab Emirates 2022-01-01                               NaN
# 2  United Arab Emirates 2021-01-01                               1.0
# 3  United Arab Emirates 2020-01-01                               0.9
# 4  United Arab Emirates 2019-01-01                               0.7
# 5  United Arab Emirates 2018-01-01                               0.3
#                  country       date  Environmental Tax Revenue (% of GDP)
# 29  United Arab Emirates 2022-01-01                                   NaN
# 30  United Arab Emirates 2021-01-01                                   NaN
# 31  United Arab Emirates 2020-01-01                                   NaN
# 32  United Arab Emirates 2019-01-01                                   NaN
# 33  United Arab Emirates 2018-01-01                                   NaN
#                 country       date  Net Trade (BoP, current US$)
# 1  United Arab Emirates 2022-01-01                           NaN
# 2  United Arab Emirates 2021-01-01                           NaN
# 3  United Arab Emirates 2020-01-01                           NaN
# 4  United Arab Emirates 2019-01-01                           NaN
# 5  United Arab Emirates 2018-01-01                           NaN
#                 country       date  Natural Gas Electricity Production (%)
# 1  United Arab Emirates 2022-01-01                                     NaN
# 2  United Arab Emirates 2021-01-01                                     NaN
# 3  United Arab Emirates 2020-01-01                                     NaN
# 4  United Arab Emirates 2019-01-01                                     NaN
# 5  United Arab Emirates 2018-01-01                                     NaN
#
# Merged Data Summary:
# Final Shape: (315, 10)

# %%
merged_data.head()
# Out:
#    country       date  GDP Growth (%)  Inflation Rate (%)  \
# 0    China 1988-01-01    3.123536e+11           33.187245
# 9    China 1989-01-01    3.477681e+11           39.242469
# 18   China 1990-01-01    3.608579e+11           40.440263
# 27   China 1991-01-01    3.833733e+11           41.878596
# 36   China 1992-01-01    4.269157e+11           44.539554
#
#     Unemployment Rate (%)  Exchange Rate (Local Currency per USD)  \
# 0                     NaN                                3.722100
# 9                     NaN                                3.765108
# 18                    NaN                                4.783208
# 27                   2.37                                5.323392
# 36                   2.37                                5.514592
#
#     Renewable Energy Consumption (%)  Environmental Tax Revenue (% of GDP)  \
# 0                                NaN                                   NaN
# 9                                NaN                                   NaN
# 18                              33.9                                   NaN
# 27                              33.1                                   NaN
# 36                              32.8                                   NaN
#
#     Net Trade (BoP, current US$)  Natural Gas Electricity Production (%)
# 0                  -4.060000e+09                                0.376552
# 9                  -4.927000e+09                                0.634223
# 18                  1.066800e+10                                0.446023
# 27                  1.160100e+10                                0.358458
# 36                  4.998000e+09                                0.327158

# %%
merged_data.tail()
# Out:
#            country       date  GDP Growth (%)  Inflation Rate (%)  \
# 278  United States 2018-01-01    2.065652e+13          115.157303
# 287  United States 2019-01-01    2.153998e+13          117.244195
# 296  United States 2020-01-01    2.135410e+13          118.690502
# 305  United States 2021-01-01    2.368117e+13          124.266414
# 314  United States 2022-01-01    2.600689e+13          134.211206
#
#      Unemployment Rate (%)  Exchange Rate (Local Currency per USD)  \
# 278                  3.896                                     1.0
# 287                  3.669                                     1.0
# 296                  8.055                                     1.0
# 305                  5.349                                     1.0
# 314                  3.650                                     1.0
#
#      Renewable Energy Consumption (%)  Environmental Tax Revenue (% of GDP)  \
# 278                               9.9                                 0.713
# 287                              10.2                                 0.713
# 296                              11.0                                 0.713
# 305                              10.9                                 0.713
# 314                              10.9                                 0.713
#
#      Net Trade (BoP, current US$)  Natural Gas Electricity Production (%)
# 278                 -5.786000e+11                               31.942161
# 287                 -5.593940e+11                               31.942161
# 296                 -6.536940e+11                               31.942161
# 305                 -8.480720e+11                               31.942161
# 314                 -9.447700e+11                               31.942161

# %%
merged_data.info()
# Out:
# <class 'wbdata.client.DataFrame'>
# Index: 315 entries, 0 to 314
# Data columns (total 10 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   country                                 315 non-null    object
#  1   date                                    315 non-null    datetime64[ns]
#  2   GDP Growth (%)                          315 non-null    float64
#  3   Inflation Rate (%)                      315 non-null    float64
#  4   Unemployment Rate (%)                   312 non-null    float64
#  5   Exchange Rate (Local Currency per USD)  315 non-null    float64
#  6   Renewable Energy Consumption (%)        313 non-null    float64
#  7   Environmental Tax Revenue (% of GDP)    291 non-null    float64
#  8   Net Trade (BoP, current US$)            315 non-null    float64
#  9   Natural Gas Electricity Production (%)  315 non-null    float64
# dtypes: datetime64[ns](1), float64(8), object(1)
# memory usage: 27.1+ KB

# %%
numeric_columns = merged_data.select_dtypes(include='number').columns
#merged_data.fillna(merged_data.median(), inplace=True)
merged_data[numeric_columns] = merged_data[numeric_columns].fillna(merged_data[numeric_columns].median())

# %%
merged_data.head()
# Out:
#    country       date  GDP Growth (%)  Inflation Rate (%)  \
# 0    China 1988-01-01    3.123536e+11           33.187245
# 9    China 1989-01-01    3.477681e+11           39.242469
# 18   China 1990-01-01    3.608579e+11           40.440263
# 27   China 1991-01-01    3.833733e+11           41.878596
# 36   China 1992-01-01    4.269157e+11           44.539554
#
#     Unemployment Rate (%)  Exchange Rate (Local Currency per USD)  \
# 0                   5.629                                3.722100
# 9                   5.629                                3.765108
# 18                  5.629                                4.783208
# 27                  2.370                                5.323392
# 36                  2.370                                5.514592
#
#     Renewable Energy Consumption (%)  Environmental Tax Revenue (% of GDP)  \
# 0                                1.1                                 1.391
# 9                                1.1                                 1.391
# 18                              33.9                                 1.391
# 27                              33.1                                 1.391
# 36                              32.8                                 1.391
#
#     Net Trade (BoP, current US$)  Natural Gas Electricity Production (%)
# 0                  -4.060000e+09                                0.376552
# 9                  -4.927000e+09                                0.634223
# 18                  1.066800e+10                                0.446023
# 27                  1.160100e+10                                0.358458
# 36                  4.998000e+09                                0.327158

# %%
merged_data.isnull().sum()
# Out:
# country                                   0
# date                                      0
# GDP Growth (%)                            0
# Inflation Rate (%)                        0
# Unemployment Rate (%)                     0
# Exchange Rate (Local Currency per USD)    0
# Renewable Energy Consumption (%)          0
# Environmental Tax Revenue (% of GDP)      0
# Net Trade (BoP, current US$)              0
# Natural Gas Electricity Production (%)    0
# dtype: int64

# %%
merged_data.rename(columns={'date': 'Date'}, inplace=True)

# %%
# to datetime
merged_data['Date'] = pd.to_datetime(merged_data['Date'])
oil_prices_df['Date'] = pd.to_datetime(oil_prices_df['Date'])

# %%
final_df = merge_with_oil_prices(merged_data, oil_prices_df)

# %%
final_df.head()
# Out:
#   country       Date  GDP Growth (%)  Inflation Rate (%)  \
# 0   China 1988-01-01    3.123536e+11           33.187245
# 1   China 1988-01-01    3.123536e+11           33.187245
# 2   China 1988-01-01    3.123536e+11           33.187245
# 3   China 1988-01-01    3.123536e+11           33.187245
# 4   China 1988-01-01    3.123536e+11           33.187245
#
#    Unemployment Rate (%)  Exchange Rate (Local Currency per USD)  \
# 0                  5.629                                  3.7221
# 1                  5.629                                  3.7221
# 2                  5.629                                  3.7221
# 3                  5.629                                  3.7221
# 4                  5.629                                  3.7221
#
#    Renewable Energy Consumption (%)  Environmental Tax Revenue (% of GDP)  \
# 0                               1.1                                 1.391
# 1                               1.1                                 1.391
# 2                               1.1                                 1.391
# 3                               1.1                                 1.391
# 4                               1.1                                 1.391
#
#    Net Trade (BoP, current US$)  Natural Gas Electricity Production (%)  year  \
# 0                 -4.060000e+09                                0.376552  1988
# 1                 -4.060000e+09                                0.376552  1988
# 2                 -4.060000e+09                                0.376552  1988
# 3                 -4.060000e+09                                0.376552  1988
# 4                 -4.060000e+09                                0.376552  1988
#
#    Price
# 0  17.95
# 1  17.08
# 2  17.90
# 3  16.88
# 4  16.65

# %%
# Create visualizations
create_visualizations(final_df, oil_prices_df)
# Out:
# 2025-02-25 10:41:51,162 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 2025-02-25 10:41:51,184 - INFO - Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
# Perform correlation analysis
correlation_results = perform_correlation_analysis(final_df)

# %%
# Plot correlation analysis results
plot_correlation_analysis(correlation_results)

# %%
# Print detailed correlation results
print("\nDetailed Correlation Analysis Results:")
print(correlation_results.sort_values('abs_correlation', ascending=False)
          .to_string(index=False))
# Out:
# Detailed Correlation Analysis Results:
#              country                              indicator  correlation  abs_correlation       p_value  significant correlation_strength  avg_rolling_correlation
#                 Iraq                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#       European Union                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#                China                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#        United States                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
# United Arab Emirates                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#   Russian Federation                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#   Iran, Islamic Rep.                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#         Saudi Arabia                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#               Kuwait                                  Price     1.000000         1.000000  0.000000e+00         True               Strong                      1.0
#               Kuwait                         GDP Growth (%)     0.910354         0.910354  0.000000e+00         True               Strong                      NaN
#               Kuwait           Net Trade (BoP, current US$)     0.902410         0.902410  0.000000e+00         True               Strong                      NaN
#   Russian Federation                         GDP Growth (%)     0.895724         0.895724  0.000000e+00         True               Strong                      NaN
#         Saudi Arabia           Net Trade (BoP, current US$)     0.863126         0.863126  0.000000e+00         True               Strong                      NaN
#   Iran, Islamic Rep.                         GDP Growth (%)     0.863029         0.863029  0.000000e+00         True               Strong                      NaN
#   Russian Federation           Net Trade (BoP, current US$)     0.824686         0.824686  0.000000e+00         True               Strong                      NaN
#       European Union                         GDP Growth (%)     0.823956         0.823956  0.000000e+00         True               Strong                      NaN
# United Arab Emirates                         GDP Growth (%)     0.803467         0.803467  0.000000e+00         True               Strong                      NaN
# United Arab Emirates Natural Gas Electricity Production (%)     0.794865         0.794865  0.000000e+00         True               Strong                      NaN
#                 Iraq Exchange Rate (Local Currency per USD)    -0.783590         0.783590  0.000000e+00         True               Strong                      NaN
#         Saudi Arabia                         GDP Growth (%)     0.766997         0.766997  0.000000e+00         True               Strong                      NaN
# United Arab Emirates                     Inflation Rate (%)    -0.751427         0.751427  0.000000e+00         True               Strong                      NaN
#                 Iraq                         GDP Growth (%)     0.741012         0.741012  0.000000e+00         True               Strong                      NaN
#        United States                     Inflation Rate (%)     0.709286         0.709286  0.000000e+00         True               Strong                      NaN
#   Russian Federation Natural Gas Electricity Production (%)     0.707986         0.707986  0.000000e+00         True               Strong                      NaN
#                China           Net Trade (BoP, current US$)     0.672455         0.672455  0.000000e+00         True             Moderate                      NaN
#        United States                         GDP Growth (%)     0.660381         0.660381  0.000000e+00         True             Moderate                      NaN
#        United States           Net Trade (BoP, current US$)    -0.659271         0.659271  0.000000e+00         True             Moderate                      NaN
#               Kuwait                     Inflation Rate (%)     0.656611         0.656611  0.000000e+00         True             Moderate                      NaN
#        United States       Renewable Energy Consumption (%)     0.649545         0.649545  0.000000e+00         True             Moderate                      NaN
#       European Union Natural Gas Electricity Production (%)     0.644373         0.644373  0.000000e+00         True             Moderate                      NaN
#        United States Natural Gas Electricity Production (%)     0.637369         0.637369  0.000000e+00         True             Moderate                      NaN
#                China Natural Gas Electricity Production (%)     0.635451         0.635451  0.000000e+00         True             Moderate                      NaN
#                China                     Inflation Rate (%)     0.635313         0.635313  0.000000e+00         True             Moderate                      NaN
#         Saudi Arabia                     Inflation Rate (%)     0.632320         0.632320  0.000000e+00         True             Moderate                      NaN
#                China       Renewable Energy Consumption (%)    -0.625618         0.625618  0.000000e+00         True             Moderate                      NaN
#       European Union       Renewable Energy Consumption (%)     0.591207         0.591207  0.000000e+00         True             Moderate                      NaN
#                China                         GDP Growth (%)     0.585665         0.585665  0.000000e+00         True             Moderate                      NaN
#   Iran, Islamic Rep.           Net Trade (BoP, current US$)     0.570586         0.570586  0.000000e+00         True             Moderate                      NaN
#                 Iraq           Net Trade (BoP, current US$)     0.541810         0.541810  0.000000e+00         True             Moderate                      NaN
# United Arab Emirates Exchange Rate (Local Currency per USD)     0.530845         0.530845  0.000000e+00         True             Moderate                      NaN
#               Kuwait Exchange Rate (Local Currency per USD)    -0.521150         0.521150  0.000000e+00         True             Moderate                      NaN
#                 Iraq Natural Gas Electricity Production (%)     0.493015         0.493015  0.000000e+00         True             Moderate                      NaN
#                 Iraq       Renewable Energy Consumption (%)     0.481850         0.481850  0.000000e+00         True             Moderate                      NaN
#   Russian Federation                     Inflation Rate (%)     0.474453         0.474453  0.000000e+00         True             Moderate                      NaN
#   Iran, Islamic Rep. Exchange Rate (Local Currency per USD)     0.451766         0.451766  0.000000e+00         True             Moderate                      NaN
#                China                  Unemployment Rate (%)     0.437254         0.437254  0.000000e+00         True             Moderate                      NaN
#   Russian Federation Exchange Rate (Local Currency per USD)     0.430336         0.430336  0.000000e+00         True             Moderate                      NaN
#   Iran, Islamic Rep.                     Inflation Rate (%)     0.399011         0.399011 1.717018e-278         True             Moderate                      NaN
#   Russian Federation                  Unemployment Rate (%)    -0.367752         0.367752 1.066791e-233         True             Moderate                      NaN
#        United States                  Unemployment Rate (%)     0.354972         0.354972 9.144631e-217         True             Moderate                      NaN
#   Iran, Islamic Rep. Natural Gas Electricity Production (%)     0.287527         0.287527 1.278596e-139         True                 Weak                      NaN
#               Kuwait       Renewable Energy Consumption (%)    -0.284518         0.284518 1.248818e-136         True                 Weak                      NaN
#   Iran, Islamic Rep.                  Unemployment Rate (%)     0.273375         0.273375 7.061396e-126         True                 Weak                      NaN
#                 Iraq                  Unemployment Rate (%)     0.231800         0.231800  4.570129e-90         True                 Weak                      NaN
# United Arab Emirates       Renewable Energy Consumption (%)     0.221359         0.221359  4.192425e-82         True                 Weak                      NaN
#   Iran, Islamic Rep.       Renewable Energy Consumption (%)    -0.215363         0.215363  1.029564e-77         True                 Weak                      NaN
#         Saudi Arabia       Renewable Energy Consumption (%)    -0.211555         0.211555  5.405801e-75         True                 Weak                      NaN
#                China Exchange Rate (Local Currency per USD)    -0.198717         0.198717  3.278102e-66         True                 Weak                      NaN
#        United States   Environmental Tax Revenue (% of GDP)    -0.172678         0.172678  3.373965e-50         True                 Weak                      NaN
#               Kuwait Natural Gas Electricity Production (%)    -0.134317         0.134317  7.050033e-31         True                 Weak                      NaN
#               Kuwait                  Unemployment Rate (%)    -0.134245         0.134245  7.585493e-31         True                 Weak                      NaN
#         Saudi Arabia                  Unemployment Rate (%)     0.131227         0.131227  1.542269e-29         True                 Weak                      NaN
#         Saudi Arabia Natural Gas Electricity Production (%)     0.098872         0.098872  2.116755e-17         True                 Weak                      NaN
# United Arab Emirates                  Unemployment Rate (%)    -0.091190         0.091190  5.081270e-15         True                 Weak                      NaN
#                 Iraq                     Inflation Rate (%)    -0.087025         0.087025  8.258509e-14         True                 Weak                      NaN
#       European Union                  Unemployment Rate (%)    -0.023023         0.023023  4.864201e-02         True                 Weak                      NaN
#   Russian Federation       Renewable Energy Consumption (%)     0.018092         0.018092  1.212931e-01        False                 Weak                      NaN
#                China   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#       European Union                     Inflation Rate (%)          NaN              NaN           NaN        False                 Weak                      NaN
#       European Union Exchange Rate (Local Currency per USD)          NaN              NaN           NaN        False                 Weak                      NaN
#       European Union   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#       European Union           Net Trade (BoP, current US$)          NaN              NaN           NaN        False                 Weak                      NaN
#   Iran, Islamic Rep.   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#                 Iraq   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#               Kuwait   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#   Russian Federation   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
#         Saudi Arabia Exchange Rate (Local Currency per USD)          NaN              NaN           NaN        False                 Weak                      NaN
#         Saudi Arabia   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
# United Arab Emirates   Environmental Tax Revenue (% of GDP)          NaN              NaN           NaN        False                 Weak                      NaN
# United Arab Emirates           Net Trade (BoP, current US$)          NaN              NaN           NaN        False                 Weak                      NaN
#        United States Exchange Rate (Local Currency per USD)          NaN              NaN           NaN        False                 Weak                      NaN

# %%
# Print summary of strongest correlations
print("\nStrongest Correlations with Oil Prices:")
strong_correlations = correlation_results[
     correlation_results['correlation_strength'] == 'Strong'
].sort_values('abs_correlation', ascending=False)
print(strong_correlations.to_string(index=False))
# Out:
# Strongest Correlations with Oil Prices:
#              country                              indicator  correlation  abs_correlation  p_value  significant correlation_strength  avg_rolling_correlation
#                China                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#       European Union                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#                 Iraq                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#   Iran, Islamic Rep.                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#         Saudi Arabia                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
# United Arab Emirates                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#   Russian Federation                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#               Kuwait                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#        United States                                  Price     1.000000         1.000000      0.0         True               Strong                      1.0
#               Kuwait                         GDP Growth (%)     0.910354         0.910354      0.0         True               Strong                      NaN
#               Kuwait           Net Trade (BoP, current US$)     0.902410         0.902410      0.0         True               Strong                      NaN
#   Russian Federation                         GDP Growth (%)     0.895724         0.895724      0.0         True               Strong                      NaN
#         Saudi Arabia           Net Trade (BoP, current US$)     0.863126         0.863126      0.0         True               Strong                      NaN
#   Iran, Islamic Rep.                         GDP Growth (%)     0.863029         0.863029      0.0         True               Strong                      NaN
#   Russian Federation           Net Trade (BoP, current US$)     0.824686         0.824686      0.0         True               Strong                      NaN
#       European Union                         GDP Growth (%)     0.823956         0.823956      0.0         True               Strong                      NaN
# United Arab Emirates                         GDP Growth (%)     0.803467         0.803467      0.0         True               Strong                      NaN
# United Arab Emirates Natural Gas Electricity Production (%)     0.794865         0.794865      0.0         True               Strong                      NaN
#                 Iraq Exchange Rate (Local Currency per USD)    -0.783590         0.783590      0.0         True               Strong                      NaN
#         Saudi Arabia                         GDP Growth (%)     0.766997         0.766997      0.0         True               Strong                      NaN
# United Arab Emirates                     Inflation Rate (%)    -0.751427         0.751427      0.0         True               Strong                      NaN
#                 Iraq                         GDP Growth (%)     0.741012         0.741012      0.0         True               Strong                      NaN
#        United States                     Inflation Rate (%)     0.709286         0.709286      0.0         True               Strong                      NaN
#   Russian Federation Natural Gas Electricity Production (%)     0.707986         0.707986      0.0         True               Strong                      NaN

# %% [markdown]
# #### Oil Prices and GDP Growth

# %%
correlation = final_df['Price'].corr(final_df['GDP Growth (%)'])
print(f"Correlation between Brent Oil Prices and GDP Growth: {correlation:.2f}")

#Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['GDP Growth (%)'], final_df['Price'], alpha=0.5, marker='o')
plt.title('Brent Oil Prices vs. GDP Growth Rates')
plt.xlabel('GDP Growth Rate (%)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and GDP Growth: 0.21

# %% [markdown]
# #### Oil Prices and Inflation Rate

# %%
correlation = final_df['Price'].corr(final_df['Inflation Rate (%)'])
print(f"Correlation between Brent Oil Prices and Inflation Rate: {correlation:.2f}")

# Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['Inflation Rate (%)'], final_df['Price'], alpha=0.5, color='blue', edgecolor='black')
plt.title('Brent Oil Prices vs. Inflation Rates')
plt.xlabel('Inflation Rate (%)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and Inflation Rate: 0.14

# %% [markdown]
# #### Oil Prices and Unemployment Rate

# %%
# Calculate the correlation
correlation = final_df['Price'].corr(final_df['Unemployment Rate (%)'])
print(f"Correlation between Brent Oil Prices and Unemployment Rate: {correlation:.2f}")

# Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['Unemployment Rate (%)'], final_df['Price'], alpha=0.5, color='green', edgecolor='black')
plt.title('Brent Oil Prices vs. Unemployment Rates')
plt.xlabel('Unemployment Rate (%)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and Unemployment Rate: 0.02

# %% [markdown]
# ### Oil Prices and Exchange Rate

# %%
# Calculate the correlation
correlation = final_df['Price'].corr(final_df['Exchange Rate (Local Currency per USD)'])
print(f"Correlation between Brent Oil Prices and Exchange Rate: {correlation:.2f}")

# Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['Exchange Rate (Local Currency per USD)'], final_df['Price'], alpha=0.5, color='purple', edgecolor='black')
plt.title('Brent Oil Prices vs. Exchange Rates')
plt.xlabel('Exchange Rate (Local Currency per USD)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and Exchange Rate: 0.11

# %% [markdown]
# ### Oil Prices and Natural Gas Electricity Production

# %%
# Calculate the correlation
correlation = final_df['Price'].corr(final_df['Natural Gas Electricity Production (%)'])
print(f"Correlation between Brent Oil Prices and Renewable Energy Consumption: {correlation:.2f}")

# Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['Natural Gas Electricity Production (%)'], final_df['Price'], alpha=0.5, color='orange', edgecolor='black')
plt.title('Brent Oil Prices vs. Natural Gas Electricity Production')
plt.xlabel('Natural Gas Electricity Production (%)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and Renewable Energy Consumption: 0.07

# %% [markdown]
# ### Oil Prices and Renewable Energy Consumption

# %%
# Calculate the correlation
correlation = final_df['Price'].corr(final_df['Renewable Energy Consumption (%)'])
print(f"Correlation between Brent Oil Prices and Renewable Energy Consumption: {correlation:.2f}")

# Visualize the relationship
plt.figure(figsize=(12, 6))
plt.scatter(final_df['Renewable Energy Consumption (%)'], final_df['Price'], alpha=0.5, color='orange', edgecolor='black')
plt.title('Brent Oil Prices vs. Renewable Energy Consumption')
plt.xlabel('Renewable Energy Consumption (%)')
plt.ylabel('Brent Oil Price (USD per barrel)')
plt.grid(True)
plt.show()
# Out:
# Correlation between Brent Oil Prices and Renewable Energy Consumption: -0.03

# %%
final_df=final_df.to_csv('../data/final_merged_data.csv')
